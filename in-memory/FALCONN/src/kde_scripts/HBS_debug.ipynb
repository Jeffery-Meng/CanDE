# %%
from fvecs import *

# %%
fpath = "/media/mydrive/distribution/ann-codes/in-memory/EXPERIMENTS/gloveN/kde_gt800.dvecs"
a = dvecs_read(fpath)
a.shape
# Out:
# (20, 1000)

# %%
a[0]
# Out:
# array([1.87909155e-02, 5.42577766e-18, 3.92704907e-03, 9.21490833e-04,
#        2.00503909e-01, 1.96061147e-04, 2.80622235e-05, 6.02159557e-07,
#        2.73462758e-06, 2.86488116e-04, 7.27121517e-05, 2.26713963e-07,
#        3.86932468e-02, 4.88287289e-10, 2.18810435e-05, 4.03838837e-02,
#        1.84098531e-01, 3.59237792e-03, 1.15216142e-03, 4.50382199e-06,
#        2.62405074e-03, 8.76100104e-04, 2.14607213e-05, 1.10402683e-02,
#        1.17584046e-05, 1.42151973e-02, 1.22652170e-04, 1.10287804e-09,
#        1.92284302e-03, 1.78449808e-02, 5.97627441e-06, 5.61969715e-01,
#        8.53850929e-07, 1.29773812e-03, 4.45026753e-13, 6.84205327e-03,
#        1.48187084e-06, 2.58128360e-04, 9.69382586e-08, 9.22272246e-05,
#        3.92436573e-02, 5.06557300e-03, 1.88911011e-02, 1.82017126e-05,
#        1.52408190e-05, 5.94241432e-02, 1.54137122e-01, 8.70204826e-02,
#        6.60626071e-01, 3.84820728e-05, 1.58242378e-07, 2.53504654e-03,
# ...
